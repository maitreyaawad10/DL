# %% [markdown]
# # Object detection using Transfer Learning of CNN architectures

# %% [markdown]
# ## installing libraries

# %%
# !pip install matplotlib
# !pip install numpy
# !pip install keras


# !wget https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# !unzip caltech-101.zip
# !tar -xvzf caltech-101/101_ObjectCategories.tar.gz
# Out:
# --2023-11-15 20:14:31--  https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-2.amazonaws.com/caltechdata/47/20/fc77-d78a-4c50-81c9-d47c2004df45/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dcaltech-101.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231115%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231115T144432Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=4e36079fcdf09e0ce20c7c1dec6ad8e63888ff5b9c39122f87dc594e969d193c [following]
# ...

# %% [markdown]
# ## import the necessary packages

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
from keras.applications import InceptionV3
from keras.layers import Dense, Flatten, MaxPooling2D
from keras.losses import CategoricalCrossentropy
from keras.metrics import CategoricalAccuracy
from keras.models import Sequential
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
# Out:
# 2023-11-15 23:31:26.131278: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-15 23:31:26.218280: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-15 23:31:26.548630: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 23:31:26.548688: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %% [markdown]
# ## preprocessing for dataset

# %%
img_generator = ImageDataGenerator(
    # rotation_range=90,
    brightness_range=(0.5, 1),
    # shear_range=0.2,
    # zoom_range=0.2,
    channel_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    rescale=1.0 / 255,
    validation_split=0.3,
)

# %%
root_dir = "101_ObjectCategories"
img_generator_flow_train = img_generator.flow_from_directory(
    directory=root_dir,
    target_size=(224, 224),
    batch_size=32,
    shuffle=True,
    subset="training",
)

img_generator_flow_valid = img_generator.flow_from_directory(
    directory=root_dir,
    target_size=(224, 224),
    batch_size=32,
    shuffle=True,
    subset="validation",
)
# Out:
# Found 6444 images belonging to 102 classes.
# Found 2700 images belonging to 102 classes.

# %%
imgs, labels = next(iter(img_generator_flow_train))

f, axarr = plt.subplots(3, 3)

for i in range(3):
    axarr[0, i].imshow(imgs[i])

for i in range(3):
    axarr[1, i].imshow(imgs[i + 3])

for i in range(3):
    axarr[2, i].imshow(imgs[i + 6])

plt.show()

# %% [markdown]
# ## load pretrained model (InceptionV3)

# %%
base_model = InceptionV3(input_shape=(224, 224, 3), include_top=False, weights="imagenet")

# %% [markdown]
# ## freeze (weights) in model's lower convolutional layers

# %%
base_model.trainable = False

# %% [markdown]
# ## add custom classifier with several layers of trainable parameters to model

# %%
model = Sequential([
        base_model,
        MaxPooling2D(),
        Flatten(),
        Dense(102, activation="softmax"),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  max_pooling2d_4 (MaxPoolin  (None, 2, 2, 2048)        0
#  g2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 102)               835686
#
# ...
# Total params: 22638470 (86.36 MB)
# Trainable params: 835686 (3.19 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %% [markdown]
# ## train classifier layers on training data available for task

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=CategoricalCrossentropy(),
    metrics=[CategoricalAccuracy()],
)

# %%
model.fit(
    img_generator_flow_train,
    validation_data=img_generator_flow_valid,
#     steps_per_epoch=5,
    epochs=5,
)
# Out:
# Epoch 1/5
# 5/5 [==============================] - 217s 53s/step - loss: 12.2424 - categorical_accuracy: 0.0750 - val_loss: 10.7589 - val_categorical_accuracy: 0.2126
# Epoch 2/5
# 5/5 [==============================] - 201s 49s/step - loss: 10.8636 - categorical_accuracy: 0.1250 - val_loss: 9.2178 - val_categorical_accuracy: 0.2593
# Epoch 3/5
# 5/5 [==============================] - 112s 27s/step - loss: 6.5012 - categorical_accuracy: 0.3688 - val_loss: 6.6322 - val_categorical_accuracy: 0.3689
# Epoch 4/5
# 5/5 [==============================] - 95s 23s/step - loss: 5.0578 - categorical_accuracy: 0.4313 - val_loss: 5.7891 - val_categorical_accuracy: 0.4167
# Epoch 5/5
# 5/5 [==============================] - 93s 23s/step - loss: 4.9986 - categorical_accuracy: 0.4750 - val_loss: 5.1448 - val_categorical_accuracy: 0.4281

# %% [markdown]
# ## plot the training loss and accuracy

# %%
H = model.history
print(H.history)
# Out:
# {'loss': [11.679801940917969, 11.132864952087402, 9.752575874328613, 7.193454742431641, 5.320839881896973], 'categorical_accuracy': [0.08124999701976776, 0.21875, 0.2750000059604645, 0.3499999940395355, 0.45625001192092896], 'val_loss': [12.862841606140137, 10.72559642791748, 7.715787887573242, 5.48183536529541, 4.751523971557617], 'val_categorical_accuracy': [0.12888889014720917, 0.20888888835906982, 0.31074073910713196, 0.4140740633010864, 0.4637036919593811]}

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 5), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 5), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 5), H.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, 5), H.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig("assign6_transfer_learning1.png")

# %% [markdown]
# ## fine-tune hyper parameters and unfreeze more layers as needed

# %%
base_model.trainable = True

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=CategoricalCrossentropy(),
    metrics=[CategoricalAccuracy()],
)

# %%
model.fit(
    img_generator_flow_train,
    validation_data=img_generator_flow_valid,
#     steps_per_epoch=5,
    epochs=5,
)

# %%
H = model.history
print(H.history)

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 5), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 5), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 5), H.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, 5), H.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig("assign6_transfer_learning2.png")
